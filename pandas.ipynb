# %%
import pandas as pd
from icecream import ic
import mglearn

# %% [markdown]
# ### pandas.DataFrame
# (data=None, index=None, columns=None, dtype=None, copy=None)
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %%
from sklearn.datasets import load_iris

iris_dataset=load_iris()
pd.DataFrame(iris_dataset.data,columns=iris_dataset.feature_names)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ### pandas.plotting

# %% [markdown]
# #### .scatter_matrix
# (frame, alpha=0.5, figsize=None, ax=None, grid=False, diagonal='hist', marker='.', density_kwds=None, hist_kwds=None, range_padding=0.05, **kwargs)
# https://pandas.pydata.org/docs/reference/api/pandas.plotting.scatter_matrix.html?highlight=plotting%20scatter

# %%
from sklearn.datasets import load_iris

iris_dataset=load_iris()
iris_dataFrame=pd.DataFrame(iris_dataset.data,columns=iris_dataset.feature_names)
grr=pd.plotting.scatter_matrix(iris_dataFrame,c=iris_dataset.target,marker="o",figsize=(15,15),range_padding=0.05,cmap='jet')

# %% [markdown]
# ### cmap(カラーマップ)一覧
# https://matplotlib.org/stable/tutorials/colors/colormaps.html
