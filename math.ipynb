# %%
import math

# %%
#Python の pow と math の pow はどう違うか？
a = pow(-2, 0.5)
print(a)  # (8.659560562354934e-17+1.4142135623730951j)
b=(-2)**0.5
print(b)
c = math.pow(-2, 0.5)
print(c)  # ValueError: math domain error

'''
0.5 乗の定義域は 0 以上の実数なので、pow(-2, 0.5) はそもそも実数の関数として定義できない(虚数になる)
よってエラーの出ているmathが正しい
'''
# Out:
# (8.659560562354934e-17+1.4142135623730951j)
# (8.659560562354934e-17+1.4142135623730951j)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-6d339cddd9ee> in <module>()
#       4 b=(-2)**0.5
#       5 print(b)
# ----> 6 c = math.pow(-2, 0.5)
#       7 print(c)  # ValueError: math domain error
#       8
#
# ValueError: math domain error
