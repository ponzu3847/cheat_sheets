# %%
from google.colab import drive

# %%
'''
google.colab.drive
.mount()

  機能： 
    Google DriveをGoogle Colaboratory上にマウントする
  使い方：
    drive.mount('/content/drive')
'''
import csv

drive.mount('/content/drive')

data=open('/content/drive/My Drive/Colab Notebooks/cheatsheets/data/access.csv')
reader = csv.DictReader(data)

for row in reader:
 print(row)
# Out:
# Mounted at /content/drive
# OrderedDict([('cost', '173'), ('sales', '1497')])
# OrderedDict([('cost', '191'), ('sales', '1488')])
# OrderedDict([('cost', '134'), ('sales', '1176')])
# OrderedDict([('cost', '100'), ('sales', '1002')])
# OrderedDict([('cost', '117'), ('sales', '1155')])
# OrderedDict([('cost', '112'), ('sales', '1161')])
# OrderedDict([('cost', '35'), ('sales', '933')])
# OrderedDict([('cost', '87'), ('sales', '930')])
# OrderedDict([('cost', '203'), ('sales', '1554')])
# OrderedDict([('cost', '50'), ('sales', '978')])
# OrderedDict([('cost', '26'), ('sales', '999')])
# OrderedDict([('cost', '163'), ('sales', '1278')])
# OrderedDict([('cost', '270'), ('sales', '1971')])
# OrderedDict([('cost', '160'), ('sales', '1203')])
# OrderedDict([('cost', '160'), ('sales', '1284')])
# OrderedDict([('cost', '60'), ('sales', '960')])
# OrderedDict([('cost', '199'), ('sales', '1569')])
# OrderedDict([('cost', '237'), ('sales', '1779')])
# ...

# %%
#google colabratoryでカスタムモジュールをインポート
#https://v-crn.hatenablog.com/entry/2019/12/30/Google_Colaboratory_%E3%81%A7%E3%82%AB%E3%82%B9%E3%82%BF%E3%83%A0%E3%83%A2%E3%82%B8%E3%83%A5%E3%83%BC%E3%83%AB%E3%82%92%E3%82%A4%E3%83%B3%E3%83%9D%E3%83%BC%E3%83%88%E3%81%99%E3%82%8B

import sys

drive.mount('/content/drive')
ROOT_PATH = 'drive/My Drive/Colab Notebooks/my_module/'
sys.path.append(ROOT_PATH)

import hello

hello.print_hello()
# Out:
# Mounted at /content/drive
# Hello!

# %%
'''
google colabのセッション切れを防止する
https://flat-kids.net/2020/07/28/google-colab-%E3%82%BB%E3%83%83%E3%82%B7%E3%83%A7%E3%83%B3%E5%88%87%E3%82%8C%E3%82%92%E9%98%B2%E6%AD%A2%E3%81%99%E3%82%8B/
F12押してConsoleウインドウに下記を入力、Enter
'''

function ClickConnect(){
  console.log("60sごとに再接続");
  document.querySelector("colab-connect-button").click()
}
setInterval(ClickConnect,1000*60);

# %% [markdown]
# ###固定幅フォントの変更方法
# chrome://settings/fonts
